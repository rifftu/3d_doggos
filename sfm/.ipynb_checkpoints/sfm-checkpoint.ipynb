# %%
from skimage import io as skio

import scipy.io
import h5py
import math
from glob import glob

# %%
import matlab.engine

# %%
from tqdm import tqdm

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
from skimage.transform import resize

# %%
breeds = [s.split('/')[-1] for s in glob('../CU_dogs/training_133/*')]
breeds.sort()

# %% [markdown]
# ### Get the all the points for a breed

# %%
# for BREED in breeds:

#     breed_mats = glob(f'CU_dogs/training_133/{BREED}/*v4.mat')

#     breed_mats.sort()


#     output = []

#     for name in breed_mats:
#         mat = scipy.io.loadmat(name)

#         img = mat['Icrop']
#         points = mat['parts']

#         scale_W = img.shape[1] / 224
#         scale_H = img.shape[0] / 224

#         points[0] = points[0]/scale_W
#         points[1] = points[1]/scale_H
#         points = np.vstack((points, np.ones(13)))


#         img = resize(img, (224, 224)) * 255
#         img = img.astype(np.uint8)

#         output.append(points)


#     scipy.io.savemat(f"2dpoints/{BREED}_points.mat", {'points':output})

# %%
top_breeds = ['005.alaskan_malamute','015.basset_hound','029.border_collie','039.bull_terrier','057.dalmatian','041.bullmastiff','087.irish_terrier','056.dachshund','016.beagle','012.australian_shepherd']

# %%
# ono = []
# for BREED in breeds:
#     ono.append(f"2dpoints/{BREED}_points.mat")

# %%
eng = matlab.engine.start_matlab()

# %%
points_raw_3d = {}
mean_points_2d = {}
motions = {}
points_meanaligned_3d = {}

# %%
for BREED in tqdm(top_breeds):
    breed_mats = glob(f'../CU_dogs/training_133/{BREED}/*v4.mat')
    breed_mats.sort()
    
    output = []
    
    total_points = np.zeros((2, 13))
    
    for name in breed_mats:
        mat = scipy.io.loadmat(name)

        img = mat['Icrop']
        points = mat['parts']

        scale_W = img.shape[1] / 224
        scale_H = img.shape[0] / 224

        points[0] = points[0]/scale_W
        points[1] = points[1]/scale_H
        
        total_points += points
        
        points = np.vstack((points, np.ones(13)))
        
        output.append(points.tolist())
        
    mean_points = total_points / len(breed_mats)
    
    mean_points_matlab = matlab.double(mean_points.tolist())
    kps_matlab = matlab.double(output)
    points_3d = eng.get3dPoints(kps_matlab)
    motion, translation = eng.getMotionTranslation(mean_points_matlab, points_3d, 2, nargout = 2)
    
    M = np.array(motion)
    T = np.array(translation).flatten()
    
    gamma = math.atan(-(M[1,2])/M[1,1])
    x_scale = M[0,0]
    y_scale = M[1,1] / math.cos(gamma)
    z_scale = (abs(x_scale) + abs(y_scale)) / 2
    scale = np.array([x_scale, y_scale, z_scale])
    
    points_3d = np.array(points_3d)
    points_raw_3d[BREED] = points_3d
    mean_points_2d[BREED] = mean_points
    motions[BREED] = {
        'M': M,
        'T': T,
        'gamma': gamma,
        'scale': scale
    }
    
    rot_mtx = np.array([
        [1, 0, 0],
        [0, math.cos(gamma), -math.sin(gamma)],
        [0, math.sin(gamma), math.cos(gamma)]
    ])
    
    
    points_rotated_3d = scale.reshape((3,1))*(rot_mtx@points_3d)
    T_3d = np.array([T[0], T[1], -min(points_rotated_3d[2])])
    
    points_meanaligned_3d[BREED] = points_rotated_3d + T_3d.reshape((3,1))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.28it/s]

# %%
plt.imshow(np.zeros((224, 224)))
plt.scatter(*(mean_points_2d['005.alaskan_malamute']))

# %%
plt.imshow(np.zeros((224, 224)))
plt.scatter(*(transformed_S))

# %% [markdown]
# ['005.alaskan_malamute','015.basset_hound','029.border_collie','039.bull_terrier','057.dalmatian','041.bullmastiff','087.irish_terrier','056.dachshund','016.beagle','012.australian_shepherd']

# %%
xdata, ydata, zdata = points_meanaligned_3d['041.bullmastiff']
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
for i in range(13): #plot each point + it's index as text above
    ax.scatter(xdata[i],ydata[i],zdata[i]) 
    ax.text(xdata[i],ydata[i],zdata[i],  '%s' % (str(i)), size=20, zorder=1,  
    color='k')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
import pickle

# %%
with open('../sfm_warp_data/3d_points.pickle', 'wb') as handle:
    pickle.dump(points_meanaligned_3d, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('../sfm_warp_data/mean_points.pickle', 'wb') as handle:
    pickle.dump(mean_points_2d, handle, protocol=pickle.HIGHEST_PROTOCOL)
